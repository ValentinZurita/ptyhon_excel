# %%
matrix = [[1, 2, 3],
[4, 5, 6],
[7, 8, 9]]

# %%
[[i + 1 for i in row] for row in matrix]
# Out:
# [[2, 3, 4], [5, 6, 7], [8, 9, 10]]

# %%
import numpy as np

# %%
array1 = np.array([10, 1000, 1000.])

# %%
array2 = np.array([[1.,2.,3.],[4.,5.,6.]])

# %%
array1.dtype
# Out:
# dtype('float64')

# %%
array2 + 1
# Out:
# array([[2., 3., 4.],
#        [5., 6., 7.]])

# %%
array2 * array2
# Out:
# array([[ 1.,  4.,  9.],
#        [16., 25., 36.]])

# %%
array2 * array1
# Out:
# array([[  10., 2000., 3000.],
#        [  40., 5000., 6000.]])
